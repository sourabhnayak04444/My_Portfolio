# %% [markdown]
# <a href="https://colab.research.google.com/github/sourabhnayak04444/My_Portfolio/blob/main/Flask_Portfolio_App.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install Flask for web app and pyngrok for the public tunnel
# !pip install Flask pyngrok

# %%
import os
import subprocess
import time
from pyngrok import ngrok
from IPython.display import display, HTML

# -------------------------------------------------------------
# 🔴 FIX: PASTE YOUR NGROK AUTHTOKEN HERE
# -------------------------------------------------------------
# Replace the placeholder string below with your actual ngrok token
NGROK_AUTH_TOKEN = "34VsGOo7Ji2LEAv2WtAVEBmmiO7_J5HVipuFbFmFTy6ugZHs"
ngrok.set_auth_token(NGROK_AUTH_TOKEN)
# -------------------------------------------------------------

# --- 1. Define File Contents as Multiline Strings ---

# Content for app.py (the Flask server logic, updated with resume data)
APP_PY_CONTENT = """
import os
from flask import Flask, render_template, request, redirect, url_for, flash

# Portfolio Details from Resume
PORTFOLIO_OWNER_NAME = "Sourabh Nayak"
PORTFOLIO_ROLE = "AIML Student & IoT Developer"
PROFILE_SUMMARY = "A passionate final-year student specializing in Artificial Intelligence and Machine Learning (AIML), with core strengths in data modeling, ML algorithms, and full-stack Python development. Dedicated to ongoing research and practical implementation of intelligent systems and IoT devices."
EDUCATION = {
    "degree": "Bachelor of Engineering in Artificial Intelligence and Machine Learning",
    "institution": "Shri Madhwa Vadiraja Institute of Technology & Management",
    "dates": "2022-2026",
    "location": "Karnataka, India"
}

# Define the Skills based on the resume (consolidated)
SKILLS = {
    "Core Programming & Database": [
        "Python (Core, ML Libraries)",
        "C, Java",
        "SQL (MySQL, MongoDB)",
        "Web Development (HTML, CSS, JS)"
    ],
    "AI/ML & Data Tools": [
        "Data Modeling & ML Algorithms",
        "Scikit-learn, TensorFlow/Keras",
        "Data Analysis (Power BI, Tableau, MS Excel)"
    ],
    "Embedded Systems & Tools": [
        "IoT Devices (Arduino, ESP32, Sensors)",
        "Jupyter Notebook, Google Colab",
        "Git, GitHub, VS Code"
    ]
}

# Define the Projects based on the resume
PROJECTS = [
    {
        "title": "Intelligent IoT Enabled Smart Fencing System",
        "description": "Designed and prototyped an intelligent IoT-based smart fence utilizing sensors and embedded logic to detect and differentiate between human and animal intrusions on agricultural land. The system triggers appropriate real-time alarms or sends alert messages based on the level and type of intrusion detected.",
        "tags": ["IoT", "Embedded Systems", "Security", "Real-Time Alerts"],
        "link": "#"
    },
    {
        "title": "Radar System for Air Defence Prototype",
        "description": "Engineered a functional prototype of a radar system using **Arduino Uno**, ultrasonic sensors, and a servo motor. The system features a developed user interface to visualize object positioning with precise angle and distance measurements, suitable for early defense applications.",
        "tags": ["Embedded C", "Arduino", "Sensors", "Signal Processing"],
        "link": "#"
    },
    {
        "title": "Attendance System using Bluetooth",
        "description": "Developed a simple and efficient check-in system where a user's presence is automatically recorded in a database (**MySQL/MongoDB**) upon connecting their device to the main control unit via **Bluetooth**. This project streamlines attendance tracking by eliminating manual entry.",
        "tags": ["Bluetooth", "Database Management", "Java/C", "Automation"],
        "link": "#"
    },
]


# Initialize the Flask application
app = Flask(__name__)
# Secret key is mandatory for 'flash' messages
app.config['SECRET_KEY'] = os.environ.get('SECRET_KEY', 'default_secret_key_for_dev')

@app.route('/')
def index():
    # Looks for index.html in the 'templates' folder and passes all data
    return render_template(
        'index.html',
        name=PORTFOLIO_OWNER_NAME,
        role=PORTFOLIO_ROLE,
        summary=PROFILE_SUMMARY,
        education=EDUCATION,
        skills=SKILLS,
        projects=PROJECTS
    )

@app.route('/contact', methods=['POST'])
def contact():
    if request.method == 'POST':
        # Safely extract form data
        name = request.form.get('name')
        email = request.form.get('email')
        message = request.form.get('message')

        # This data is printed to the Colab console (where the background Flask process is running)
        print(f"\\n[Flask Background] --- NEW CONTACT MESSAGE RECEIVED ---")
        print(f"[Flask Background] Name: {name}")
        print(f"[Flask Background] Email: {email}")
        print(f"[Flask Background] Message: {message}")
        print(f"[Flask Background] ----------------------------------\\n")

        # Flash a success message
        flash('Thank you for your message! I will be in touch soon.', 'success')

        # Redirect back to the homepage
        return redirect(url_for('index'))
    return redirect(url_for('index'))

# This block is what the subprocess will run
if __name__ == '__main__':
    # Important: Setting use_reloader=False for stability when running via subprocess
    app.run(host='0.0.0.0', port=5000, debug=True, use_reloader=False)
"""

# %%
# Content for templates/index.html (the responsive portfolio page, updated with Jinja loops and contact form)
INDEX_HTML_CONTENT = """
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>{{ name }} | {{ role }} Portfolio</title>
    <!-- Load Tailwind CSS for easy styling -->
    <script src="https://cdn.tailwindcss.com"></script>
    <style>
        @import url('https://fonts.googleapis.com/css2?family=Inter:wght@400;600;700&display=swap');
        body {
            font-family: 'Inter', sans-serif;
            background-color: #f4f6f8;
            color: #1e293b;
        }
    </style>
</head>
<body class="min-h-screen">

    <!-- Navbar -->
    <header class="bg-white shadow-lg sticky top-0 z-10">
        <div class="max-w-7xl mx-auto px-4 sm:px-6 lg:px-8 py-4 flex justify-between items-center">
            <a href="#" class="text-2xl font-bold text-indigo-600 hover:text-indigo-800 transition duration-300">{{ name }}</a>
            <nav class="space-x-4">
                <a href="#about" class="text-gray-600 hover:text-indigo-600 transition duration-300 font-medium">About</a>
                <a href="#education" class="text-gray-600 hover:text-indigo-600 transition duration-300 font-medium">Education</a>
                <a href="#skills" class="text-gray-600 hover:text-indigo-600 transition duration-300 font-medium">Skills</a>
                <a href="#projects" class="text-gray-600 hover:text-indigo-600 transition duration-300 font-medium">Projects</a>
                <a href="#contact" class="text-gray-600 hover:text-indigo-600 transition duration-300 font-medium">Contact</a>
            </nav>
        </div>
    </header>

    <!-- Success/Flash Message Display (uses Jinja2 from Flask) -->
    {% with messages = get_flashed_messages(with_categories=true) %}
        {% if messages %}
            <div class="max-w-xl mx-auto mt-4 px-4">
                {% for category, message in messages %}
                    {% if category == 'success' %}
                        <div class="bg-green-100 border border-green-400 text-green-700 px-4 py-3 rounded-md shadow-md" role="alert">
                            <p class="font-bold">Success!</p>
                            <p class="text-sm">{{ message }}</p>
                        </div>
                    {% endif %}
                {% endfor %}
            </div>
        {% endif %}
    {% endwith %}


    <main class="max-w-7xl mx-auto px-4 sm:px-6 lg:px-8 py-12 space-y-20">

        <!-- Hero Section -->
        <section id="hero" class="text-center py-20 bg-white rounded-xl shadow-2xl">
            <div class="max-w-3xl mx-auto">
                <img class="mx-auto h-32 w-32 rounded-full object-cover mb-6 border-4 border-indigo-500 shadow-md"
                        src="https://placehold.co/128x128/3B82F6/ffffff?text=SN"
                        alt="{{ name }} Profile Picture">
                <h1 class="text-5xl font-extrabold text-gray-900 mb-4 leading-tight">
                    Hello, I'm {{ name }}.
                </h1>
                <p class="text-2xl text-indigo-600 font-light mb-8">
                    {{ role }}
                </p>
                <p class="text-lg text-gray-600 max-w-2xl mx-auto">
                    {{ summary }}
                </p>
                <div class="mt-8 space-x-4">
                    <a href="#projects" class="inline-block px-8 py-3 bg-indigo-600 text-white font-semibold rounded-lg shadow-md hover:bg-indigo-700 transition duration-300 transform hover:scale-105">View Projects</a>
                    <a href="#contact" class="inline-block px-8 py-3 border border-indigo-600 text-indigo-600 font-semibold rounded-lg shadow-md hover:bg-indigo-50 transition duration-300">Get In Touch</a>
                </div>
            </div>
        </section>

        <!-- About Section -->
        <section id="about" class="bg-white p-10 rounded-xl shadow-lg">
            <h2 class="text-4xl font-bold text-gray-900 mb-6 border-b-2 border-indigo-300 pb-2">About Me</h2>
            <div class="grid md:grid-cols-1 gap-8 text-gray-700">
                <p>
                    {{ summary }}
                </p>
            </div>
        </section>

        <!-- Education Section -->
        <section id="education" class="bg-white p-10 rounded-xl shadow-lg">
            <h2 class="text-4xl font-bold text-gray-900 mb-6 border-b-2 border-indigo-300 pb-2">Education</h2>
            <div class="bg-indigo-50 p-6 rounded-lg shadow-sm border border-indigo-200">
                <h3 class="text-xl font-bold text-indigo-800">{{ education.degree }}</h3>
                <p class="text-lg text-gray-700 font-medium mt-1">{{ education.institution }}, {{ education.location }}</p>
                <p class="text-md text-gray-500 mt-1">Expected Graduation: {{ education.dates }}</p>
            </div>
        </section>

        <!-- Skills Section (Dynamic Rendering) -->
        <section id="skills" class="bg-white p-10 rounded-xl shadow-lg">
            <h2 class="text-4xl font-bold text-gray-900 mb-8 border-b-2 border-indigo-300 pb-2">Technical Skills</h2>
            <div class="grid md:grid-cols-3 gap-8">
                {% for category, items in skills.items() %}
                <div class="bg-gray-50 p-6 rounded-lg shadow-md border-t-4 border-indigo-500">
                    <h3 class="text-xl font-semibold text-indigo-600 mb-3">{{ category }}</h3>
                    <ul class="list-disc list-inside space-y-2 text-gray-700 pl-4">
                        {% for item in items %}
                        <li>{{ item }}</li>
                        {% endfor %}
                    </ul>
                </div>
                {% endfor %}
            </div>
        </section>

        <!-- Projects Section (Dynamic Rendering) -->
        <section id="projects" class="bg-white p-10 rounded-xl shadow-lg">
            <h2 class="text-4xl font-bold text-gray-900 mb-8 border-b-2 border-indigo-300 pb-2">Featured Projects</h2>
            <div class="grid md:grid-cols-2 lg:grid-cols-3 gap-8">
                {% for project in projects %}
                <div class="bg-gray-50 p-6 rounded-lg shadow-md border-t-4 border-indigo-500 hover:shadow-xl transition duration-300">
                    <h3 class="text-xl font-semibold text-gray-900 mb-2">{{ project.title }}</h3>
                    <p class="text-gray-600 mb-4 text-sm">{{ project.description }}</p>
                    <div class="flex flex-wrap gap-2 mb-4">
                        {% for tag in project.tags %}
                        <span class="bg-indigo-100 text-indigo-700 text-xs font-medium px-3 py-1 rounded-full">{{ tag }}</span>
                        {% endfor %}
                    </div>
                    <a href="{{ project.link }}" class="text-indigo-500 hover:text-indigo-700 font-semibold text-sm flex items-center group">
                        View Details
                        <!-- Simple Arrow Icon using SVG -->
                        <svg class="w-4 h-4 ml-1 transform group-hover:translate-x-1 transition duration-200" fill="none" stroke="currentColor" viewBox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path stroke-linecap="round" stroke-linejoin="round" stroke-width="2" d="M14 5l7 7m0 0l-7 7m7-7H3"></path></svg>
                    </a>
                </div>
                {% endfor %}
            </div>
        </section>


        <!-- Contact Form Section -->
        <section id="contact" class="bg-indigo-50 p-10 rounded-xl shadow-inner">
            <h2 class="text-4xl font-bold text-gray-900 mb-8 border-b-2 border-indigo-600 pb-2">Get In Touch</h2>

            <div class="max-w-lg mx-auto bg-white p-8 rounded-lg shadow-2xl">
                <p class="text-gray-700 mb-6">Have a question or a project idea? Send me a message!</p>

                <!-- Flask Form Action: Submits to the '/contact' route -->
                <form action="/contact" method="POST" class="space-y-6">
                    <div>
                        <label for="name" class="block text-sm font-medium text-gray-700">Name</label>
                        <input type="text" name="name" id="name" required
                                class="mt-1 block w-full px-4 py-2 border border-gray-300 rounded-md shadow-sm focus:border-indigo-500 focus:ring-indigo-500 transition duration-200"
                                placeholder="Your Name">
                    </div>

                    <div>
                        <label for="email" class="block text-sm font-medium text-gray-700">Email</label>
                        <input type="email" name="email" id="email" required
                                class="mt-1 block w-full px-4 py-2 border border-gray-300 rounded-md shadow-sm focus:border-indigo-500 focus:ring-indigo-500 transition duration-200"
                                placeholder="your.email@example.com">
                    </div>

                    <div>
                        <label for="message" class="block text-sm font-medium text-gray-700">Message</label>
                        <textarea name="message" id="message" rows="4" required
                                    class="mt-1 block w-full px-4 py-2 border border-gray-300 rounded-md shadow-sm focus:border-indigo-500 focus:ring-indigo-500 transition duration-200"
                                    placeholder="What would you like to discuss?"></textarea>
                    </div>

                    <button type="submit"
                            class="w-full flex justify-center py-3 px-4 border border-transparent rounded-md shadow-sm text-lg font-medium text-white bg-indigo-600 hover:bg-indigo-700 focus:outline-none focus:ring-2 focus:ring-offset-2 focus:ring-indigo-500 transition duration-300 transform hover:scale-[1.01]">
                        Send Message
                    </button>
                </form>
            </div>
        </section>

    </main>

    <!-- Footer -->
    <footer class="bg-gray-800 text-white mt-12">
        <div class="max-w-7xl mx-auto px-4 sm:px-6 lg:px-8 py-6 text-center">
            <p>&copy; 2025 {{ name }} Portfolio. Built with Python and Flask.</p>
            <div class="mt-2 space-x-4 text-sm">
                <!-- Links updated from Resume -->
                <a href="https://www.linkedin.com/in/sourabhnayak044" target="_blank" class="hover:text-indigo-400">LinkedIn</a>
                <a href="https://github.com/sourabhnayak04444" target="_blank" class="hover:text-indigo-400">GitHub</a>
            </div>
        </div>
    </footer>

</body>
</html>
"""

# --- 2. File Creation ---
print("--- Creating required directories and files ---")

# Create the 'templates' folder required by Flask
# !mkdir -p templates

# Write the content to the files
with open("app.py", "w") as f:
    f.write(APP_PY_CONTENT)
print("File 'app.py' created.")

with open("templates/index.html", "w") as f:
    f.write(INDEX_HTML_CONTENT)
print("File 'templates/index.html' created with updated portfolio data.")

# --- 3. Run the Flask Server and ngrok Tunnel ---
print("\n--- Starting Flask server and creating public tunnel ---")

# Terminate any existing ngrok tunnels
ngrok.kill()

# Start the Flask app as a non-blocking background process
# Use -u (unbuffered) to ensure logs appear immediately
flask_process = subprocess.Popen(['python', '-u', 'app.py'], stdout=subprocess.PIPE, stderr=subprocess.PIPE)
time.sleep(5) # Give the Flask server enough time to initialize

if flask_process.poll() is not None:
    # Process failed to start
    print("\n\t🔴 ERROR: Flask server failed to start. Check the logs above for details.")
    error_output = flask_process.stderr.read().decode()
    print("-" * 50)
    print(error_output)
    print("-" * 50)
else:
    # Flask process started successfully, now tunnel it with ngrok
    print("Server started successfully. Creating ngrok tunnel...")

    try:
        # Connect ngrok to the Flask port (5000)
        public_url = ngrok.connect(5000).public_url

        print(f"\n--- 🚀 Flask Portfolio App is LIVE! ---")
        # --- START CHANGE HERE ---
        # Updated the display text to include the owner's name
        display(HTML(f'<h2><a href="{public_url}" target="_blank" style="color:#4c51bf;">Click here to view **Sourabh Nayak\'s** Portfolio Website</a></h2>'))
        # --- END CHANGE HERE ---
        print(f"Public URL: {public_url}")
        print("\n--- The server is now running. Do NOT close or stop this cell. ---")
        print("--- To shut down the server, click the **STOP** button (□) on the left. ---")

        # Keep the main process alive so the server stays active
        while True:
            time.sleep(1)

    except Exception as e:
        print(f"\n\t🔴 ERROR: Failed to create ngrok tunnel: {e}")
        print("Please ensure your NGROK_AUTH_TOKEN is correct and try again.")
    finally:
        # Ensure the Flask background process is terminated if the cell stops or errors
        if flask_process:
            flask_process.terminate()
            flask_process.wait()
            print("\nFlask process terminated.")
# Out:
# --- Creating required directories and files ---
# File 'app.py' created.
# File 'templates/index.html' created with updated portfolio data.
#
# --- Starting Flask server and creating public tunnel ---
# Server started successfully. Creating ngrok tunnel...
#
# --- 🚀 Flask Portfolio App is LIVE! ---
# <h2><a href="https://archangelical-claudette-rabidly.ngrok-free.dev" target="_blank" style="color:#4c51bf;">Click here to view **Sourabh Nayak's** Portfolio Website</a></h2>
# Public URL: https://archangelical-claudette-rabidly.ngrok-free.dev
#
# --- The server is now running. Do NOT close or stop this cell. ---
# --- To shut down the server, click the **STOP** button (□) on the left. ---
